# %% [markdown]
#  **Earthquake Prediction **

# %% [markdown]
# Importing Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib
matplotlib.style.use('ggplot')
# %matplotlib inline

# %%
# prompt: google drive mount

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Project/Dataset/edata.csv')

# %%
df.head()
# Out:
#        Lat      Lon  Mag  Depth km     Timestamp  \
# 0  36.1657  69.8792  4.0    115.08  1.491588e+09
# 1  14.4749  93.0560  5.3     33.64  1.491411e+09
# 2  36.1320  71.3585  4.9    102.03  1.491342e+09
# 3  36.3580  68.9443  4.6     32.17  1.491101e+09
# 4  36.5656  70.0559  4.0    229.25  1.490999e+09
#
#                              Region
# 0    HINDU KUSH REGION- AFGHANISTAN
# 1     ANDAMAN ISLANDS- INDIA REGION
# 2  AFGHANISTAN-TAJIKISTAN BORD REG.
# 3    HINDU KUSH REGION- AFGHANISTAN
# 4    HINDU KUSH REGION- AFGHANISTAN

# %%
#del  df['Year'], df['Month'], df['Day'], df['Timestamp']

# %%
df
# Out:
#            Lat      Lon  Mag  Depth km     Timestamp  \
# 0      36.1657  69.8792  4.0    115.08  1.491588e+09
# 1      14.4749  93.0560  5.3     33.64  1.491411e+09
# 2      36.1320  71.3585  4.9    102.03  1.491342e+09
# 3      36.3580  68.9443  4.6     32.17  1.491101e+09
# 4      36.5656  70.0559  4.0    229.25  1.490999e+09
# ...        ...      ...  ...       ...           ...
# 29996  34.4260  73.6410  3.7     81.80  1.020678e+09
# 29997  35.8270  89.7220  3.8     33.00  1.020627e+09
# 29998  30.6750  84.0370  3.6     33.00  1.020618e+09
# 29999  36.4620  71.5580  3.9    101.80  1.020615e+09
# 30000  21.1420  72.8900  2.8     15.00  1.020595e+09
#
#                                  Region
# 0        HINDU KUSH REGION- AFGHANISTAN
# 1         ANDAMAN ISLANDS- INDIA REGION
# 2      AFGHANISTAN-TAJIKISTAN BORD REG.
# 3        HINDU KUSH REGION- AFGHANISTAN
# 4        HINDU KUSH REGION- AFGHANISTAN
# ...                                 ...
# ...

# %%
df.describe()
# Out:
#                 Lat           Lon           Mag      Depth km     Timestamp
# count  30001.000000  30001.000000  30001.000000  30001.000000  3.000100e+04
# mean      29.741660     84.171109      3.642189     41.631607  1.183535e+09
# std        8.120915     12.951488      0.744079     59.322665  9.797604e+07
# min        9.801000     64.511600      0.500000      0.000000  1.020595e+09
# 25%       25.910000     71.310600      3.200000      8.100000  1.113009e+09
# 50%       32.270000     81.251000      3.600000     15.000000  1.182125e+09
# 75%       36.459900     95.019800      4.100000     39.800000  1.245618e+09
# max       37.720000    107.570000      7.900000    750.000000  1.491588e+09

# %%
import pandas as pd
from pandas.plotting import scatter_matrix

axs = scatter_matrix(df, figsize=(12, 12), diagonal='kde')
# Calculate correlation only for numeric columns
df.select_dtypes(include=np.number).corr() # Select only numeric columns before calling corr
# Out:
#                 Lat       Lon       Mag  Depth km  Timestamp
# Lat        1.000000 -0.495225 -0.145453  0.274528   0.036998
# Lon       -0.495225  1.000000  0.121816 -0.358431   0.048579
# Mag       -0.145453  0.121816  1.000000  0.095128   0.248799
# Depth km   0.274528 -0.358431  0.095128  1.000000   0.124278
# Timestamp  0.036998  0.048579  0.248799  0.124278   1.000000

# %%
df = pd.get_dummies(df, columns = ['Region'])

# %%
df.head()
# Out:
#        Lat      Lon  Mag  Depth km     Timestamp  Region_AFGHANISTAN  \
# 0  36.1657  69.8792  4.0    115.08  1.491588e+09               False
# 1  14.4749  93.0560  5.3     33.64  1.491411e+09               False
# 2  36.1320  71.3585  4.9    102.03  1.491342e+09               False
# 3  36.3580  68.9443  4.6     32.17  1.491101e+09               False
# 4  36.5656  70.0559  4.0    229.25  1.490999e+09               False
#
#    Region_AFGHANISTAN-TAJIKISTAN BORD REG.  Region_ANDAMAN ISLANDS- INDIA  \
# 0                                    False                          False
# 1                                    False                          False
# 2                                     True                          False
# 3                                    False                          False
# 4                                    False                          False
#
#    Region_ANDAMAN ISLANDS- INDIA REGION  Region_ARABIAN SEA  ...  \
# ...

# %%
import sklearn
import sklearn.pipeline
import sklearn.preprocessing  # Import preprocessing module
import sklearn.svm

# Assuming you want to use StandardScaler for feature scaling:
mapper = sklearn.preprocessing.StandardScaler()  # Define and instantiate mapper

pipe = sklearn.pipeline.make_pipeline(mapper, sklearn.svm.SVC())

# %%
X = df.copy()
del X['Mag']
y = df.Mag

# %%
y
# Out:
# 0        4.0
# 1        5.3
# 2        4.9
# 3        4.6
# 4        4.0
#         ...
# 29996    3.7
# 29997    3.8
# 29998    3.6
# 29999    3.9
# 30000    2.8
# Name: Mag, Length: 30001, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)
